# %% [markdown]
# # 01. Exploratory Data Analysis (EDA) - Raw IPL Dataset
# **Project**: IPL Performance Analytics Using Data Science and Analytics
# **College**: TY B.Sc. Data Science
#
# This notebook inspects the raw IPL match and delivery datasets, analyzes dimensions, column data types, missing value distributions, and basic match attributes.

# %%
import os
import sys
import pandas as pd
import numpy as np
sys.path.insert(0, '..')
from src.preprocessing.data_loader import IPLDataLoader

# Load raw datasets
loader = IPLDataLoader('..')
df_matches, df_deliveries = loader.load_raw_data()
print('Matches Shape:', df_matches.shape)
print('Deliveries Shape:', df_deliveries.shape)

# %% [markdown]
# ### Raw Matches Schema & Info

# %%
df_matches.info()
df_matches.head()

# %% [markdown]
# ### Raw Deliveries Schema & Sample Records

# %%
df_deliveries.info()
df_deliveries.head()

# %% [markdown]
# ### Missing Value Analysis

# %%
print('Matches Missing Values:')
print(df_matches.isna().sum()[df_matches.isna().sum() > 0])

print('\nDeliveries Missing Values:')
print(df_deliveries.isna().sum()[df_deliveries.isna().sum() > 0])
