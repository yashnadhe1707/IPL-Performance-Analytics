# %% [markdown]
# # 07. Project Evaluation & Integrity Verification
# **Project**: IPL Performance Analytics Using Data Science and Analytics
# **College**: TY B.Sc. Data Science
#
# Executes end-to-end data quality checks, mathematical consistency verification, and dashboard component integrity scoring.

# %%
import sys
sys.path.insert(0, '..')
from evaluation.evaluate_data_quality import run_data_quality_evaluation
from evaluation.evaluate_statistics import run_statistics_evaluation
from evaluation.evaluate_dashboard import run_dashboard_evaluation

print('1. Running Data Quality Evaluation...')
dq_rep = run_data_quality_evaluation()

print('\n2. Running Statistics Validation...')
stats_rep = run_statistics_evaluation()

print('\n3. Running Dashboard Responsiveness Evaluation...')
dash_rep = run_dashboard_evaluation()

print('\nFinal Evaluation Status: ALL CHECKS PASSED!')
